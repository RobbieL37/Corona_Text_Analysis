# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from wordcloud import WordCloud
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import pos_tag
from nltk.util import ngrams
import plotly.express as px
import scipy.stats
import math
import statistics
import string 
import re
from collections import defaultdict
from gensim import corpora, models

# %% [markdown]
# 8 data (x)
# ranking negative(1-3) positive(4,5) (x)
# single words + Bi-grame + Tri-gram

# %% [markdown]
# ### Import all the data

# %%
# data importing 
lowes_6026 = pd.read_csv('C:\\Users\\lxf12\\Desktop\\Folder of folders\\Corona New project\\Lowes_Homedepot_Reviews\\lowes.com_3286026.csv')
lowes_0314 = pd.read_csv('C:\\Users\\lxf12\\Desktop\\Folder of folders\\Corona New project\\Lowes_Homedepot_Reviews\\lowes.com_3380314.csv')
lowes_0511 = pd.read_csv('C:\\Users\\lxf12\\Desktop\\Folder of folders\\Corona New project\\Lowes_Homedepot_Reviews\\lowes.com_50280511.csv') 
lowes_6162 = pd.read_csv('C:\\Users\\lxf12\\Desktop\\Folder of folders\\Corona New project\\Lowes_Homedepot_Reviews\\lowes.com_1003066162.csv')
lowes_6209 = pd.read_csv('C:\\Users\\lxf12\\Desktop\\Folder of folders\\Corona New project\\Lowes_Homedepot_Reviews\\lowes.com_5000026209.csv')
lowes_9855 = pd.read_csv('C:\\Users\\lxf12\\Desktop\\Folder of folders\\Corona New project\\Lowes_Homedepot_Reviews\\lowes.com_5001899855.csv')

# %%
# data importing 
homedepot_4796 = pd.read_csv('C:\\Users\\lxf12\\Desktop\\Folder of folders\\Corona New project\\Lowes_Homedepot_Reviews\\homedepot.com_204074796.csv')
homedepot_7071 = pd.read_csv('C:\\Users\\lxf12\\Desktop\\Folder of folders\\Corona New project\\Lowes_Homedepot_Reviews\\homedepot.com_319247071.csv')

# %%
# set display option to max to see all information in review column
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\lxf12\AppData\Local\Temp\ipykernel_9880\779606820.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
lowes_0314.head(2)
# Out:
#   Market_place  \
# 0  lowes.com
# 1  lowes.com
#
#                                                                                                                                            URL  \
# 0  https://www.lowes.com/pd/American-Standard-Saver-White-WaterSense-Labeled-Elongated-Chair-Height-2-piece-Toilet-12-in-Rough-In-Size/3380314
# 1  https://www.lowes.com/pd/American-Standard-Saver-White-WaterSense-Labeled-Elongated-Chair-Height-2-piece-Toilet-12-in-Rough-In-Size/3380314
#
#                                                                                                           Product_name  \
# 0  American Standard  Saver White Elongated Chair Height 2-piece WaterSense Toilet 12-in Rough-In Size (Ada Compliant)
# 1  American Standard  Saver White Elongated Chair Height 2-piece WaterSense Toilet 12-in Rough-In Size (Ada Compliant)
#
#                     SKU  Price Currency               Subject   Author  \
# 0  Model #710FA.101.020  179.0  USD      Need Quality Control  USAF157
# 1  Model #710FA.101.020  179.0  USD      Good Flush            EddieD
#
#                Date  \
# 0  December 7, 2020
# 1  April 12, 2013
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Review  \
# 0  Nice design with poor quality control. Tank leaked during install. Had to replace fill valve and remove excess porcelain cement from fill valve opening to make it smooth and round.
# 1  I have bought other toilets for a rental. Sometimes there isn't much water in the bowl. Without enough water in bowl, you may need to clean the bowl much more often than usual, if you know what I mean. This toilet does hold a good amount of water in bowl. As far as people saying they need to flush 2 or 3 times....all you need to do is hold down the flushing handle for an extra 1-2 seconds and you get more water flushing from the tank through the bowl. (Quick flush for # 1 and Hold down lever longer for a long flush for #2). It does have a cheap seat, but I used the seat I had instead. The Wax Ring is good. It is deep for a good seal and it has the flange on it. Don't forget to get a very long water supply line. If not sure how long, just get the longest one they have. If too long, you can just twist it into a circle. You'll never see it behind the toilet. This is a high toilet (17 1/2 inches to top of seat). My wife is 5' 4" . She said " any higher she would need a step stool" but she likes the height. We have been using this for over a month now with no complaints or concerns.
#
#    Stars  like  dislike
# 0  1      0     0
# 1  5      21    1

# %%
# drop null value
datalist = [lowes_6026, lowes_0314, lowes_0511, lowes_6162,
                    lowes_6209, lowes_9855, 
                     homedepot_4796, homedepot_7071]
namelist = ['lowes_6026', 'lowes_0314', 'lowes_0511', 'lowes_6162',
                    'lowes_6209', 'lowes_9855', 
                     'homedepot_4796', 'homedepot_7071']
n = 0 

for i in datalist: 
    # drop rows with Not a Number (NaN) and None values
    name = namelist[n]
    n += 1
    print(name + ' has null rows amount: '+ str(i['Review'].isna().sum()))
    i.dropna(subset=['Review'], inplace=True)
    print('after cleaning, ' + name + ' has null rows amount: ' 
          + str(i['Review'].isna().sum()))
# Out:
# lowes_6026 has null rows amount: 30
# after cleaning, lowes_6026 has null rows amount: 0
# lowes_0314 has null rows amount: 10
# after cleaning, lowes_0314 has null rows amount: 0
# lowes_0511 has null rows amount: 15
# after cleaning, lowes_0511 has null rows amount: 0
# lowes_6162 has null rows amount: 297
# after cleaning, lowes_6162 has null rows amount: 0
# lowes_6209 has null rows amount: 76
# after cleaning, lowes_6209 has null rows amount: 0
# lowes_9855 has null rows amount: 170
# after cleaning, lowes_9855 has null rows amount: 0
# homedepot_4796 has null rows amount: 186
# after cleaning, homedepot_4796 has null rows amount: 0
# homedepot_7071 has null rows amount: 9
# after cleaning, homedepot_7071 has null rows amount: 0

# %%
lowes_9855.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 114
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Market_place  100 non-null    object
#  1   URL           100 non-null    object
#  2   Product_name  100 non-null    object
#  3   SKU           100 non-null    object
#  4   Price         100 non-null    float64
#  5   Currency      100 non-null    object
#  6   Subject       100 non-null    object
#  7   Author        95 non-null     object
#  8   Date          100 non-null    object
#  9   Review        100 non-null    object
#  10  Stars         100 non-null    int64
#  11  like          100 non-null    int64
#  12  dislike       100 non-null    int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 10.9+ KB

# %%
datalist[0].isna().sum()
# Out:
# Market_place    0
# URL             0
# Product_name    0
# SKU             0
# Price           0
# Currency        0
# Subject         48
# Author          11
# Date            0
# Review          0
# Stars           0
# like            0
# dislike         0
# dtype: int64

# %% [markdown]
# ### Separate Negative and Positive Ranking

# %%
# 8 data x 2 categories 
try:
    user_select = int(input("Please select negative(0) or positive ranking(1): "))
except: 
    print("Your input is not correct. Please input again according the tips.")

if user_select == 0:
    # get reviews that have given 1, 2, and 3 stars (negative)
    lowes_6026 = lowes_6026.loc[lowes_6026['Stars'] <= 3]
    lowes_0314 = lowes_0314.loc[lowes_0314['Stars'] <= 3]
    lowes_0511 = lowes_0511.loc[lowes_0511['Stars'] <= 3]
    lowes_6162 = lowes_6162.loc[lowes_6162['Stars'] <= 3]
    lowes_6209 = lowes_6209.loc[lowes_6209['Stars'] <= 3]
    lowes_9855 = lowes_9855.loc[lowes_9855['Stars'] <= 3]
    # get reviews that have given 1, 2, and 3 stars (negative)
    homedepot_4796 = homedepot_4796.loc[homedepot_4796['Stars'] <= 3]
    homedepot_7071 = homedepot_7071.loc[homedepot_7071['Stars'] <= 3]
elif user_select == 1:
    # get reviews that have given 4 and 5 stars (positive)
    lowes_6026 = lowes_6026.loc[lowes_6026['Stars'] > 3]
    lowes_0314 = lowes_0314.loc[lowes_0314['Stars'] > 3]
    lowes_0511 = lowes_0511.loc[lowes_0511['Stars'] > 3]
    lowes_6162 = lowes_6162.loc[lowes_6162['Stars'] > 3]
    lowes_6209 = lowes_6209.loc[lowes_6209['Stars'] > 3]
    lowes_9855 = lowes_9855.loc[lowes_9855['Stars'] > 3]
    # get reviews that have given 4 and 5 stars (positive)
    homedepot_4796 = homedepot_4796.loc[homedepot_4796['Stars'] > 3]
    homedepot_7071 = homedepot_7071.loc[homedepot_7071['Stars'] > 3]
else: 
    print("Your input is not correct. Please input again according the tips.")
# Out:
# Please select negative(0) or positive ranking(1): 2
# Your input is not correct. Please input again according the tips.

# %%
lowes_0314.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 390 entries, 0 to 392
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Market_place  390 non-null    object
#  1   URL           390 non-null    object
#  2   Product_name  390 non-null    object
#  3   SKU           390 non-null    object
#  4   Price         390 non-null    float64
#  5   Currency      390 non-null    object
#  6   Subject       381 non-null    object
#  7   Author        370 non-null    object
#  8   Date          390 non-null    object
#  9   Review        390 non-null    object
#  10  Stars         390 non-null    int64
#  11  like          390 non-null    int64
#  12  dislike       390 non-null    int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 42.7+ KB

# %% [markdown]
# ### Lower case for all words & Remove punctuation

# %%
# download package punkt for word_tokenize
# nltk.download('punkt')
# download package for stopwords
# nltk.download('stopwords')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('wordnet')
# nltk.download('omw-1.4')

# %%
# before the cleaning 
text_01 = lowes_6026['Review'].to_string(index=False)
# text_01

# %%
# Create a translation table with all punctuation characters mapped to None
translator = str.maketrans('', '', string.punctuation)

text = [0] * 8
n = 0 

for i in datalist:
    # convert pandas series data to string
    text[n] = i['Review'].to_string(index=False)
    # convert all characters to lowercase
    text[n] = text[n].lower()
    # remove punctuations using RegexpTokenizer
    text[n] = text[n].translate(translator)
    # Use regex to remove all numbers
    text[n] = re.sub(r'\d+', '', text[n])
    n += 1

# %%
# the result has been single words 
# text[0]

# %%
type(text[0])
# Out:
# str

# %% [markdown]
# ### Stop words

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    # customize stop_words by including a custom list of words
#     custom_stop_words = ['new','toilet', 'factory', 'flush', 'sku', 'photos', 'stay', 
#                                      'lid', 'good', 'great', 'handle', 'top', 'high', 'urine']
#     stop_words.update(custom_stop_words)
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lxf12\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
for i in range(8):
    text[i] = remove_stopwords(text[i])

# %%
# text[0]

# %%
# text[7]

# %% [markdown]
# ### Text Tokenization

# %%
# remove punctuations using RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
tokens = [0] * 8
for i in range(8):
    tokens[i] = tokenizer.tokenize(text[i])

# %%
# tokens[0]

# %% [markdown]
# ### Bi-gram and Tri-gram

# %%
# N-gram generation
N = int(input('Which one do you want to look at? (0-7)'))

trigrams = [0] * 8
for i in range(8):
    trigrams[i] = list(ngrams(tokens[i], N))
# Out:
# Which one do you want to look at? (0-7)4

# %%
trigrams[6]
# Out:
# [('purchased', 'toilets', 'new', 'house'),
#  ('toilets', 'new', 'house', 'pool'),
#  ('new', 'house', 'pool', 'water'),
#  ('house', 'pool', 'water', 'bowl'),
#  ('pool', 'water', 'bowl', 'small'),
#  ('water', 'bowl', 'small', 'often'),
#  ('bowl', 'small', 'often', 'resulting'),
#  ('small', 'often', 'resulting', 'solid'),
#  ('often', 'resulting', 'solid', 'waste'),
#  ('resulting', 'solid', 'waste', 'smeared'),
#  ('solid', 'waste', 'smeared', 'well'),
#  ('waste', 'smeared', 'well', 'water'),
#  ('smeared', 'well', 'water', 'line'),
#  ('well', 'water', 'line', 'flushing'),
#  ('water', 'line', 'flushing', 'easily'),
#  ('line', 'flushing', 'easily', 'remove'),
#  ('flushing', 'easily', 'remove', 'one'),
#  ('easily', 'remove', 'one', 'four'),
#  ('remove', 'one', 'four', 'toilets'),
#  ('one', 'four', 'toilets', 'normal'),
#  ('four', 'toilets', 'normal', 'sized'),
#  ('toilets', 'normal', 'sized', 'pool'),
#  ('normal', 'sized', 'pool', 'water'),
#  ('sized', 'pool', 'water', 'clear'),
#  ('pool', 'water', 'clear', 'manufactured'),
#  ('water', 'clear', 'manufactured', 'along'),
#  ('clear', 'manufactured', 'along', 'different'),
#  ('manufactured', 'along', 'different', 'printing'),
#  ('along', 'different', 'printing', 'tank'),
#  ('different', 'printing', 'tank', 'despite'),
#  ('printing', 'tank', 'despite', 'sku'),
#  ('tank', 'despite', 'sku', 'number'),
#  ('despite', 'sku', 'number', 'included'),
#  ('sku', 'number', 'included', 'photos'),
#  ('number', 'included', 'photos', 'variations'),
#  ('included', 'photos', 'variations', 'markings'),
#  ('photos', 'variations', 'markings', 'recently'),
#  ('variations', 'markings', 'recently', 'bought'),
#  ('markings', 'recently', 'bought', 'chair'),
#  ('recently', 'bought', 'chair', 'height'),
#  ('bought', 'chair', 'height', 'elongated'),
#  ('chair', 'height', 'elongated', 'toilet'),
#  ('height', 'elongated', 'toilet', 'second'),
#  ('elongated', 'toilet', 'second', 'one'),
#  ('toilet', 'second', 'one', 'bought'),
#  ('second', 'one', 'bought', 'one'),
#  ('one', 'bought', 'one', 'bathroom'),
#  ('bought', 'one', 'bathroom', 'bought'),
#  ('one', 'bathroom', 'bought', 'years'),
#  ('bathroom', 'bought', 'years', 'ago'),
#  ('bought', 'years', 'ago', 'since'),
#  ('years', 'ago', 'since', 'didn'),
#  ('ago', 'since', 'didn', 't'),
#  ('since', 'didn', 't', 'issues'),
#  ('didn', 't', 'issues', 'first'),
#  ('t', 'issues', 'first', 'one'),
#  ('issues', 'first', 'one', 'purchased'),
#  ('first', 'one', 'purchased', 'another'),
#  ('one', 'purchased', 'another', 'bad'),
#  ('purchased', 'another', 'bad', 'decision'),
#  ('another', 'bad', 'decision', 'quality'),
#  ('bad', 'decision', 'quality', 'really'),
#  ('decision', 'quality', 'really', 'declined'),
#  ('quality', 'really', 'declined', 'cheap'),
#  ('really', 'declined', 'cheap', 'flimsy'),
#  ('declined', 'cheap', 'flimsy', 'seating'),
#  ('cheap', 'flimsy', 'seating', 'lid'),
#  ('flimsy', 'seating', 'lid', 'stay'),
#  ('seating', 'lid', 'stay', 'connected'),
#  ('lid', 'stay', 'connected', 'line'),
#  ('stay', 'connected', 'line', 'disappointed'),
#  ('connected', 'line', 'disappointed', 'guess'),
#  ('line', 'disappointed', 'guess', 'toilets'),
#  ('disappointed', 'guess', 'toilets', 'displayed'),
#  ('guess', 'toilets', 'displayed', 'high'),
#  ('toilets', 'displayed', 'high', 'cannot'),
#  ('displayed', 'high', 'cannot', 'check'),
#  ('high', 'cannot', 'check', 'buy'),
#  ('cannot', 'check', 'buy', 'nice'),
#  ('check', 'buy', 'nice', 'color'),
#  ('buy', 'nice', 'color', 'sits'),
#  ('nice', 'color', 'sits', 'great'),
#  ('color', 'sits', 'great', 'height'),
#  ('sits', 'great', 'height', 'getting'),
#  ('great', 'height', 'getting', 'happy'),
#  ('height', 'getting', 'happy', 'low'),
#  ('getting', 'happy', 'low', 'water'),
#  ('happy', 'low', 'water', 'levelbut'),
#  ('low', 'water', 'levelbut', 'water'),
#  ('water', 'levelbut', 'water', 'saving'),
#  ('levelbut', 'water', 'saving', 'thingso'),
#  ('water', 'saving', 'thingso', 'good'),
#  ('saving', 'thingso', 'good', 'toileti'),
#  ('thingso', 'good', 'toileti', 'didnt'),
#  ('good', 'toileti', 'didnt', 'like'),
#  ('toileti', 'didnt', 'like', 'plastic'),
#  ('didnt', 'like', 'plastic', 'seat'),
#  ('like', 'plastic', 'seat', 'changed'),
#  ('plastic', 'seat', 'changed', 'one'),
#  ('seat', 'changed', 'one', 'see'),
#  ('changed', 'one', 'see', 'picture'),
#  ('one', 'see', 'picture', 'toilet'),
#  ('see', 'picture', 'toilet', 'great'),
#  ('picture', 'toilet', 'great', 'value'),
#  ('toilet', 'great', 'value', 'looks'),
#  ('great', 'value', 'looks', 'performs'),
#  ('value', 'looks', 'performs', 'perfectly'),
#  ('looks', 'performs', 'perfectly', 'high'),
#  ('performs', 'perfectly', 'high', 'efficiency'),
#  ('perfectly', 'high', 'efficiency', 'quiet'),
#  ('high', 'efficiency', 'quiet', 'attractive'),
#  ('efficiency', 'quiet', 'attractive', 'looks'),
#  ('quiet', 'attractive', 'looks', 'good'),
#  ('attractive', 'looks', 'good', 'easy'),
#  ('looks', 'good', 'easy', 'install'),
#  ('good', 'easy', 'install', 'issues'),
#  ('easy', 'install', 'issues', 'included'),
#  ('install', 'issues', 'included', 'wax'),
#  ('issues', 'included', 'wax', 'seal'),
#  ('included', 'wax', 'seal', 'plastic'),
#  ('wax', 'seal', 'plastic', 'insert'),
#  ('seal', 'plastic', 'insert', 'need'),
#  ('plastic', 'insert', 'need', 'buy'),
#  ('insert', 'need', 'buy', 'no'),
#  ('need', 'buy', 'no', 'wax'),
#  ('buy', 'no', 'wax', 'seal'),
#  ('no', 'wax', 'seal', 'that'),
#  ('wax', 'seal', 'that', 's'),
#  ('seal', 'that', 's', 'high'),
#  ('that', 's', 'high', 'slight'),
#  ('s', 'high', 'slight', 'ceramic'),
#  ('high', 'slight', 'ceramic', 'imperfection'),
#  ('slight', 'ceramic', 'imperfection', 'seat'),
#  ('ceramic', 'imperfection', 'seat', 'lid'),
#  ('imperfection', 'seat', 'lid', 'flushes'),
#  ('seat', 'lid', 'flushes', 'well'),
#  ('lid', 'flushes', 'well', 'hold'),
#  ('flushes', 'well', 'hold', 'longer'),
#  ('well', 'hold', 'longer', 'solids'),
#  ('hold', 'longer', 'solids', 'seat'),
#  ('longer', 'solids', 'seat', 'little'),
#  ('solids', 'seat', 'little', 'cheap'),
#  ('seat', 'little', 'cheap', 'works'),
#  ('little', 'cheap', 'works', 'terrible'),
#  ('cheap', 'works', 'terrible', 'product'),
#  ('works', 'terrible', 'product', 'bowl'),
#  ('terrible', 'product', 'bowl', 'wont'),
#  ('product', 'bowl', 'wont', 'stay'),
#  ('bowl', 'wont', 'stay', 'full'),
#  ('wont', 'stay', 'full', 'flushing'),
#  ('stay', 'full', 'flushing', 'power'),
#  ('full', 'flushing', 'power', 'weak'),
#  ('flushing', 'power', 'weak', 'unable'),
#  ('power', 'weak', 'unable', 'return'),
#  ('weak', 'unable', 'return', 'installed'),
#  ('unable', 'return', 'installed', 'home'),
#  ('return', 'installed', 'home', 'depot'),
#  ('installed', 'home', 'depot', 'ashamed'),
#  ('home', 'depot', 'ashamed', 'carrying'),
#  ('depot', 'ashamed', 'carrying', 'horrible'),
#  ('ashamed', 'carrying', 'horrible', 'product'),
#  ('carrying', 'horrible', 'product', 'negative'),
#  ('horrible', 'product', 'negative', 'reviews'),
#  ('product', 'negative', 'reviews', 'already'),
#  ('negative', 'reviews', 'already', 'covered'),
#  ('reviews', 'already', 'covered', 'issues'),
#  ('already', 'covered', 'issues', 'seat'),
#  ('covered', 'issues', 'seat', 'wont'),
#  ('issues', 'seat', 'wont', 'stay'),
#  ('seat', 'wont', 'stay', 'rating'),
#  ('wont', 'stay', 'rating', 'provided'),
#  ('stay', 'rating', 'provided', 'verified'),
#  ('rating', 'provided', 'verified', 'purchaser'),
#  ('provided', 'verified', 'purchaser', 'elegant'),
#  ('verified', 'purchaser', 'elegant', 'appearance'),
#  ('purchaser', 'elegant', 'appearance', 'comfortable'),
#  ('elegant', 'appearance', 'comfortable', 'little'),
#  ('appearance', 'comfortable', 'little', 'darker'),
#  ('comfortable', 'little', 'darker', 'expected'),
#  ('little', 'darker', 'expected', 'trying'),
#  ('darker', 'expected', 'trying', 'match'),
#  ('expected', 'trying', 'match', 'told'),
#  ('trying', 'match', 'told', 'almond'),
#  ('match', 'told', 'almond', 'colored'),
#  ('told', 'almond', 'colored', 'tub'),
#  ('almond', 'colored', 'tub', 'works'),
#  ('colored', 'tub', 'works', 'blends'),
#  ('tub', 'works', 'blends', 'well'),
#  ('works', 'blends', 'well', 'colors'),
#  ('blends', 'well', 'colors', 'new'),
#  ('well', 'colors', 'new', 'bathroom'),
#  ('colors', 'new', 'bathroom', 'cannot'),
#  ('new', 'bathroom', 'cannot', 'comment'),
#  ('bathroom', 'cannot', 'comment', 'assembly'),
#  ('cannot', 'comment', 'assembly', 'professionally'),
#  ('comment', 'assembly', 'professionally', 'installed'),
#  ('assembly', 'professionally', 'installed', 'however'),
#  ('professionally', 'installed', 'however', 'hear'),
#  ('installed', 'however', 'hear', 'complaints'),
#  ('however', 'hear', 'complaints', 'installer'),
#  ('hear', 'complaints', 'installer', 'looks'),
#  ('complaints', 'installer', 'looks', 'exactly'),
#  ('installer', 'looks', 'exactly', 'like'),
#  ('looks', 'exactly', 'like', 'picture'),
#  ('exactly', 'like', 'picture', 'complaint'),
#  ('like', 'picture', 'complaint', 'call'),
#  ('picture', 'complaint', 'call', 'complaint'),
#  ('complaint', 'call', 'complaint', 'sometimes'),
#  ('call', 'complaint', 'sometimes', 'i'),
#  ('complaint', 'sometimes', 'i', 've'),
#  ('sometimes', 'i', 've', 'noticed'),
#  ('i', 've', 'noticed', 'may'),
#  ('ve', 'noticed', 'may', 'flush'),
#  ('noticed', 'may', 'flush', 'twice'),
#  ('may', 'flush', 'twice', 'ensure'),
#  ('flush', 'twice', 'ensure', 'everything'),
#  ('twice', 'ensure', 'everything', 'goes'),
#  ('ensure', 'everything', 'goes', 'it'),
#  ('everything', 'goes', 'it', 's'),
#  ('goes', 'it', 's', 'liquids'),
#  ('it', 's', 'liquids', 'goes'),
#  ('s', 'liquids', 'goes', 'one'),
#  ('liquids', 'goes', 'one', 'flush'),
#  ('goes', 'one', 'flush', 'ive'),
#  ('one', 'flush', 'ive', 'month'),
#  ('flush', 'ive', 'month', 'far'),
#  ('ive', 'month', 'far', 'leaks'),
#  ('month', 'far', 'leaks', 'issues'),
#  ('far', 'leaks', 'issues', 'i'),
#  ('leaks', 'issues', 'i', 'm'),
#  ('issues', 'i', 'm', 'happy'),
#  ('i', 'm', 'happy', 'purchase'),
#  ('m', 'happy', 'purchase', 'toilet'),
#  ('happy', 'purchase', 'toilet', 'way'),
#  ('purchase', 'toilet', 'way', 'high'),
#  ('toilet', 'way', 'high', 'actual'),
#  ('way', 'high', 'actual', 'measurements'),
#  ('high', 'actual', 'measurements', 'match'),
#  ('actual', 'measurements', 'match', 'box'),
#  ('measurements', 'match', 'box', 'says'),
#  ('match', 'box', 'says', 'first'),
#  ('box', 'says', 'first', 'thing'),
#  ('says', 'first', 'thing', 'noticed'),
#  ('first', 'thing', 'noticed', 'several'),
#  ('thing', 'noticed', 'several', 'holes'),
#  ('noticed', 'several', 'holes', 'porcelain'),
#  ('several', 'holes', 'porcelain', 'front'),
#  ('holes', 'porcelain', 'front', 'toilet'),
#  ('porcelain', 'front', 'toilet', 'bowl'),
#  ('front', 'toilet', 'bowl', 'see'),
#  ('toilet', 'bowl', 'see', 'images'),
#  ('bowl', 'see', 'images', 'would'),
#  ('see', 'images', 'would', 'much'),
#  ('images', 'would', 'much', 'trouble'),
#  ('would', 'much', 'trouble', 'put'),
#  ('much', 'trouble', 'put', 'everything'),
#  ('trouble', 'put', 'everything', 'back'),
#  ('put', 'everything', 'back', 'box'),
#  ('everything', 'back', 'box', 'return'),
#  ('back', 'box', 'return', 'store'),
#  ('box', 'return', 'store', 'unit'),
#  ('return', 'store', 'unit', 'never'),
#  ('store', 'unit', 'never', 'left'),
#  ('unit', 'never', 'left', 'factory'),
#  ('never', 'left', 'factory', 'quality'),
#  ('left', 'factory', 'quality', 'control'),
#  ('factory', 'quality', 'control', 'also'),
#  ('quality', 'control', 'also', 'matter'),
#  ('control', 'also', 'matter', 'cant'),
#  ('also', 'matter', 'cant', 'get'),
#  ('matter', 'cant', 'get', 'seat'),
#  ('cant', 'get', 'seat', 'stay'),
#  ('get', 'seat', 'stay', 'im'),
#  ('seat', 'stay', 'im', 'butt'),
#  ('stay', 'im', 'butt', 'loves'),
#  ('im', 'butt', 'loves', 'taller'),
#  ('butt', 'loves', 'taller', 'usual'),
#  ('loves', 'taller', 'usual', 'toilet'),
#  ('taller', 'usual', 'toilet', 'flush'),
#  ('usual', 'toilet', 'flush', 'sufficient'),
#  ('toilet', 'flush', 'sufficient', 'enough'),
#  ('flush', 'sufficient', 'enough', 'get'),
#  ('sufficient', 'enough', 'get', 'business'),
#  ('enough', 'get', 'business', 'oval'),
#  ('get', 'business', 'oval', 'shape'),
#  ('business', 'oval', 'shape', 'gives'),
#  ('oval', 'shape', 'gives', 'room'),
#  ('shape', 'gives', 'room', 'sitting'),
#  ('gives', 'room', 'sitting', 'found'),
#  ('room', 'sitting', 'found', 'tack'),
#  ('sitting', 'found', 'tack', 'cracked'),
#  ('found', 'tack', 'cracked', 'water'),
#  ('tack', 'cracked', 'water', 'bathroom'),
#  ('cracked', 'water', 'bathroom', 'less'),
#  ('water', 'bathroom', 'less', 'months'),
#  ('bathroom', 'less', 'months', 'old'),
#  ('less', 'months', 'old', 'since'),
#  ('months', 'old', 'since', 'purchased'),
#  ('old', 'since', 'purchased', 'contacted'),
#  ('since', 'purchased', 'contacted', 'manufacture'),
#  ('purchased', 'contacted', 'manufacture', 'customer'),
#  ('contacted', 'manufacture', 'customer', 'service'),
#  ('manufacture', 'customer', 'service', 'get'),
#  ('customer', 'service', 'get', 'replacement'),
#  ('service', 'get', 'replacement', 'services'),
#  ('get', 'replacement', 'services', 'slow'),
#  ('replacement', 'services', 'slow', 'glacier'),
#  ('services', 'slow', 'glacier', 'bay'),
#  ('slow', 'glacier', 'bay', 'toilet'),
#  ('glacier', 'bay', 'toilet', 'bathroom'),
#  ('bay', 'toilet', 'bathroom', 'working'),
#  ('toilet', 'bathroom', 'working', 'fine'),
#  ('bathroom', 'working', 'fine', 'decade'),
#  ('working', 'fine', 'decade', 'disappointed'),
#  ('fine', 'decade', 'disappointed', 'black'),
#  ('decade', 'disappointed', 'black', 'toilet'),
#  ('disappointed', 'black', 'toilet', 'stairs'),
#  ('black', 'toilet', 'stairs', 'tiles'),
#  ('toilet', 'stairs', 'tiles', 'still'),
#  ('stairs', 'tiles', 'still', 'needs'),
#  ('tiles', 'still', 'needs', 'repair'),
#  ('still', 'needs', 'repair', 'still'),
#  ('needs', 'repair', 'still', 'finishing'),
#  ('repair', 'still', 'finishing', 'black'),
#  ('still', 'finishing', 'black', 'bathrooms'),
#  ('finishing', 'black', 'bathrooms', 'take'),
#  ('black', 'bathrooms', 'take', 'get'),
#  ('bathrooms', 'take', 'get', 'done'),
#  ('take', 'get', 'done', 'got'),
#  ('get', 'done', 'got', 'black'),
#  ('done', 'got', 'black', 'toilets'),
#  ('got', 'black', 'toilets', 'like'),
#  ('black', 'toilets', 'like', 'past'),
#  ('toilets', 'like', 'past', 'year'),
#  ('like', 'past', 'year', 'cheap'),
#  ('past', 'year', 'cheap', 'plastic'),
#  ('year', 'cheap', 'plastic', 'seat'),
#  ('cheap', 'plastic', 'seat', 'part'),
#  ('plastic', 'seat', 'part', 'toilet'),
#  ('seat', 'part', 'toilet', 'biscuit'),
#  ('part', 'toilet', 'biscuit', 'rest'),
#  ('toilet', 'biscuit', 'rest', 'toilet'),
#  ('biscuit', 'rest', 'toilet', 'white'),
#  ('rest', 'toilet', 'white', 'matching'),
#  ('toilet', 'white', 'matching', 'seat'),
#  ('white', 'matching', 'seat', 'disapointed'),
#  ('matching', 'seat', 'disapointed', 'paid'),
#  ('seat', 'disapointed', 'paid', 'extra'),
#  ('disapointed', 'paid', 'extra', 'could'),
#  ('paid', 'extra', 'could', 'toilet'),
#  ('extra', 'could', 'toilet', 'seat'),
#  ('could', 'toilet', 'seat', 'somewhat'),
#  ('toilet', 'seat', 'somewhat', 'match'),
#  ('seat', 'somewhat', 'match', 'vanity'),
#  ('somewhat', 'match', 'vanity', 'came'),
#  ('match', 'vanity', 'came', 'see'),
#  ('vanity', 'came', 'see', 'could'),
#  ('came', 'see', 'could', 'buy'),
#  ('see', 'could', 'buy', 'replacement'),
#  ('could', 'buy', 'replacement', 'tank'),
#  ('buy', 'replacement', 'tank', 'literally'),
#  ('replacement', 'tank', 'literally', 'saw'),
#  ('tank', 'literally', 'saw', 'thing'),
#  ('literally', 'saw', 'thing', 'happened'),
#  ('saw', 'thing', 'happened', 'someone'),
#  ('thing', 'happened', 'someone', 'else'),
#  ('happened', 'someone', 'else', 'woke'),
#  ('someone', 'else', 'woke', 'back'),
#  ('else', 'woke', 'back', 'tank'),
#  ('woke', 'back', 'tank', 'cracked'),
#  ('back', 'tank', 'cracked', 'alittle'),
#  ('tank', 'cracked', 'alittle', 'years'),
#  ('cracked', 'alittle', 'years', 'toilet'),
#  ('alittle', 'years', 'toilet', 'trash'),
#  ('years', 'toilet', 'trash', 'woke'),
#  ('toilet', 'trash', 'woke', 'tank'),
#  ('trash', 'woke', 'tank', 'making'),
#  ('woke', 'tank', 'making', 'loud'),
#  ('tank', 'making', 'loud', 'pop'),
#  ('making', 'loud', 'pop', 'ran'),
#  ('loud', 'pop', 'ran', 'bathroom'),
#  ('pop', 'ran', 'bathroom', 'see'),
#  ('ran', 'bathroom', 'see', 'tank'),
#  ('bathroom', 'see', 'tank', 'leaking'),
#  ('see', 'tank', 'leaking', 'place'),
#  ('tank', 'leaking', 'place', 'rating'),
#  ('leaking', 'place', 'rating', 'provided'),
#  ('place', 'rating', 'provided', 'verified'),
#  ('rating', 'provided', 'verified', 'purchaser'),
#  ('provided', 'verified', 'purchaser', 'looks'),
#  ('verified', 'purchaser', 'looks', 'like'),
#  ('purchaser', 'looks', 'like', 'theyve'),
#  ('looks', 'like', 'theyve', 'changed'),
#  ('like', 'theyve', 'changed', 'manufacturers'),
#  ('theyve', 'changed', 'manufacturers', 'model'),
#  ('changed', 'manufacturers', 'model', 'number'),
#  ('manufacturers', 'model', 'number', 'new'),
#  ('model', 'number', 'new', 'model'),
#  ('number', 'new', 'model', 'isnt'),
#  ('new', 'model', 'isnt', 'measurements'),
#  ('model', 'isnt', 'measurements', 'specifications'),
#  ('isnt', 'measurements', 'specifications', 'website'),
#  ('measurements', 'specifications', 'website', 'design'),
#  ('specifications', 'website', 'design', 'base'),
#  ('website', 'design', 'base', 'hole'),
#  ('design', 'base', 'hole', 'base'),
#  ('base', 'hole', 'base', 'basically'),
#  ('hole', 'base', 'basically', 'straight'),
#  ('base', 'basically', 'straight', 'back'),
#  ('basically', 'straight', 'back', 'instead'),
#  ('straight', 'back', 'instead', 'slightly'),
#  ('back', 'instead', 'slightly', 'inset'),
#  ('instead', 'slightly', 'inset', 'doesnt'),
#  ('slightly', 'inset', 'doesnt', 'fit'),
#  ('inset', 'doesnt', 'fit', 'bathroom'),
#  ('doesnt', 'fit', 'bathroom', 'without'),
#  ('fit', 'bathroom', 'without', 'taking'),
#  ('bathroom', 'without', 'taking', 'trim'),
#  ('without', 'taking', 'trim', 'whatnot'),
#  ('taking', 'trim', 'whatnot', 'addition'),
#  ('trim', 'whatnot', 'addition', 'several'),
#  ('whatnot', 'addition', 'several', 'obvious'),
#  ('addition', 'several', 'obvious', 'glaze'),
#  ('several', 'obvious', 'glaze', 'imperfections'),
#  ('obvious', 'glaze', 'imperfections', 'would'),
#  ('glaze', 'imperfections', 'would', 'still'),
#  ('imperfections', 'would', 'still', 'visible'),
#  ('would', 'still', 'visible', 'assembled'),
#  ('still', 'visible', 'assembled', 'returning'),
#  ('visible', 'assembled', 'returning', 'toilet'),
#  ('assembled', 'returning', 'toilet', 'met'),
#  ('returning', 'toilet', 'met', 'expectationswe'),
#  ('toilet', 'met', 'expectationswe', 'satisfied'),
#  ('met', 'expectationswe', 'satisfied', 'far'),
#  ('expectationswe', 'satisfied', 'far', 'toilet'),
#  ('satisfied', 'far', 'toilet', 'reasonably'),
#  ('far', 'toilet', 'reasonably', 'priced'),
#  ('toilet', 'reasonably', 'priced', 'recommended'),
#  ('reasonably', 'priced', 'recommended', 'plumber'),
#  ('priced', 'recommended', 'plumber', 'bought'),
#  ('recommended', 'plumber', 'bought', 'old'),
#  ('plumber', 'bought', 'old', 'one'),
#  ('bought', 'old', 'one', 'got'),
#  ('old', 'one', 'got', 'stained'),
#  ('one', 'got', 'stained', 'selling'),
#  ('got', 'stained', 'selling', 'house'),
#  ('stained', 'selling', 'house', 'installing'),
#  ('selling', 'house', 'installing', 'new'),
#  ('house', 'installing', 'new', 'one'),
#  ('installing', 'new', 'one', 'house'),
#  ('new', 'one', 'house', 'showed'),
#  ('one', 'house', 'showed', 'well'),
#  ('house', 'showed', 'well', 'sold'),
#  ('showed', 'well', 'sold', 'within'),
#  ('well', 'sold', 'within', 'weeks'),
#  ('sold', 'within', 'weeks', 'full'),
#  ('within', 'weeks', 'full', 'price'),
#  ('weeks', 'full', 'price', 'easy'),
#  ('full', 'price', 'easy', 'jnstall'),
#  ('price', 'easy', 'jnstall', 'color'),
#  ('easy', 'jnstall', 'color', 'goes'),
#  ('jnstall', 'color', 'goes', 'great'),
#  ('color', 'goes', 'great', 'bathroom'),
#  ('goes', 'great', 'bathroom', 'simple'),
#  ('great', 'bathroom', 'simple', 'easy'),
#  ('bathroom', 'simple', 'easy', 'install'),
#  ('simple', 'easy', 'install', 'bought'),
#  ('easy', 'install', 'bought', 'went'),
#  ('install', 'bought', 'went', 'easy'),
#  ('bought', 'went', 'easy', 'although'),
#  ('went', 'easy', 'although', 'need'),
#  ('easy', 'although', 'need', 'get'),
#  ('although', 'need', 'get', 'double'),
#  ('need', 'get', 'double', 'wax'),
#  ('get', 'double', 'wax', 'ring'),
#  ('double', 'wax', 'ring', 'one'),
#  ('wax', 'ring', 'one', 'get'),
#  ('ring', 'one', 'get', 'good'),
#  ('one', 'get', 'good', 'seal'),
#  ('get', 'good', 'seal', 'work'),
#  ('good', 'seal', 'work', 'look'),
#  ('seal', 'work', 'look', 'great'),
#  ('work', 'look', 'great', 'base'),
#  ('look', 'great', 'base', 'little'),
#  ('great', 'base', 'little', 'longer'),
#  ('base', 'little', 'longer', 'previous'),
#  ('little', 'longer', 'previous', 'toilets'),
#  ('longer', 'previous', 'toilets', 'remove'),
#  ('previous', 'toilets', 'remove', 'trim'),
#  ('toilets', 'remove', 'trim', 'base'),
#  ('remove', 'trim', 'base', 'board'),
#  ('trim', 'base', 'board', 'bathroom'),
#  ('base', 'board', 'bathroom', 'also'),
#  ('board', 'bathroom', 'also', 'sits'),
#  ('bathroom', 'also', 'sits', 'higher'),
#  ('also', 'sits', 'higher', 'needed'),
#  ('sits', 'higher', 'needed', 'add'),
#  ('higher', 'needed', 'add', 'risers'),
#  ('needed', 'add', 'risers', 'john'),
#  ('add', 'risers', 'john', 'tank'),
#  ('risers', 'john', 'tank', 'lid'),
#  ('john', 'tank', 'lid', 'could'),
#  ('tank', 'lid', 'could', 'removed'),
#  ('lid', 'could', 'removed', 'need'),
#  ('could', 'removed', 'need', 'overall'),
#  ('removed', 'need', 'overall', 'satisfied'),
#  ('need', 'overall', 'satisfied', 'pleased'),
#  ('overall', 'satisfied', 'pleased', 'nice'),
#  ('satisfied', 'pleased', 'nice', 'looked'),
#  ('pleased', 'nice', 'looked', 'installed'),
#  ('nice', 'looked', 'installed', 'great'),
#  ('looked', 'installed', 'great', 'less'),
#  ('installed', 'great', 'less', 'expensive'),
#  ('great', 'less', 'expensive', 'option'),
#  ('less', 'expensive', 'option', 'classic'),
#  ('expensive', 'option', 'classic', 'look'),
#  ('option', 'classic', 'look', 'replaced'),
#  ('classic', 'look', 'replaced', 'two'),
#  ('look', 'replaced', 'two', 'round'),
#  ('replaced', 'two', 'round', 'bowl'),
#  ('two', 'round', 'bowl', 'toilets'),
#  ('round', 'bowl', 'toilets', 'although'),
#  ('bowl', 'toilets', 'although', 'elongated'),
#  ('toilets', 'although', 'elongated', 'bowl'),
#  ('although', 'elongated', 'bowl', 'still'),
#  ('elongated', 'bowl', 'still', 'fit'),
#  ('bowl', 'still', 'fit', 'space'),
#  ('still', 'fit', 'space', 'adjacent'),
#  ('fit', 'space', 'adjacent', 'shower'),
#  ('space', 'adjacent', 'shower', 'fine'),
#  ('adjacent', 'shower', 'fine', 'easy'),
#  ('shower', 'fine', 'easy', 'put'),
#  ('fine', 'easy', 'put', 'togeather'),
#  ('easy', 'put', 'togeather', 'install'),
#  ('put', 'togeather', 'install', 'purchased'),
#  ('togeather', 'install', 'purchased', 'commode'),
#  ('install', 'purchased', 'commode', 'years'),
#  ('purchased', 'commode', 'years', 'ago'),
#  ('commode', 'years', 'ago', 'starting'),
#  ('years', 'ago', 'starting', 'fracture'),
#  ('ago', 'starting', 'fracture', 'bottom'),
#  ('starting', 'fracture', 'bottom', 'bowl'),
#  ('fracture', 'bottom', 'bowl', 'acceptable'),
#  ('bottom', 'bowl', 'acceptable', 'toilet'),
#  ('bowl', 'acceptable', 'toilet', 'clogs'),
#  ('acceptable', 'toilet', 'clogs', 'easilyit'),
#  ('toilet', 'clogs', 'easilyit', 'doesnt'),
#  ('clogs', 'easilyit', 'doesnt', 'much'),
#  ('easilyit', 'doesnt', 'much', 'capacityi'),
#  ('doesnt', 'much', 'capacityi', 'call'),
#  ('much', 'capacityi', 'call', 'plumber'),
#  ('capacityi', 'call', 'plumber', 'within'),
#  ('call', 'plumber', 'within', 'week'),
#  ('plumber', 'within', 'week', 'purchasing'),
#  ('within', 'week', 'purchasing', 'perfect'),
#  ('week', 'purchasing', 'perfect', 'toilet'),
#  ('purchasing', 'perfect', 'toilet', 'bought'),
#  ('perfect', 'toilet', 'bought', 'toilet'),
#  ('toilet', 'bought', 'toilet', 'height'),
#  ('bought', 'toilet', 'height', 'bought'),
#  ('toilet', 'height', 'bought', 'one'),
#  ('height', 'bought', 'one', 'liked'),
#  ('bought', 'one', 'liked', 'wobbles'),
#  ('one', 'liked', 'wobbles', 'buy'),
#  ('liked', 'wobbles', 'buy', 'spacers'),
#  ('wobbles', 'buy', 'spacers', 'plastic'),
#  ('buy', 'spacers', 'plastic', 'home'),
#  ('spacers', 'plastic', 'home', 'depot'),
#  ('plastic', 'home', 'depot', 'flushes'),
#  ('home', 'depot', 'flushes', 'good'),
#  ('depot', 'flushes', 'good', 'fast'),
#  ('flushes', 'good', 'fast', 'pleased'),
#  ('good', 'fast', 'pleased', 'product'),
#  ('fast', 'pleased', 'product', 'priceeasy'),
#  ('pleased', 'product', 'priceeasy', 'put'),
#  ('product', 'priceeasy', 'put', 'place'),
#  ('priceeasy', 'put', 'place', 'pleasantly'),
#  ('put', 'place', 'pleasantly', 'surprised'),
#  ('place', 'pleasantly', 'surprised', 'see'),
#  ('pleasantly', 'surprised', 'see', 'float'),
#  ('surprised', 'see', 'float', 'flushing'),
#  ('see', 'float', 'flushing', 'components'),
#  ('float', 'flushing', 'components', 'place'),
#  ('flushing', 'components', 'place', 'ready'),
#  ('components', 'place', 'ready', 'usethank'),
#  ('place', 'ready', 'usethank', 'product'),
#  ('ready', 'usethank', 'product', 'meant'),
#  ('usethank', 'product', 'meant', 'last'),
#  ('product', 'meant', 'last', 'weigh'),
#  ('meant', 'last', 'weigh', 'around'),
#  ('last', 'weigh', 'around', 'lbs'),
#  ('weigh', 'around', 'lbs', 'cracked'),
#  ('around', 'lbs', 'cracked', 'bottom'),
#  ('lbs', 'cracked', 'bottom', 'pics'),
#  ('cracked', 'bottom', 'pics', 'attached'),
#  ('bottom', 'pics', 'attached', 'ready'),
#  ('pics', 'attached', 'ready', 'replace'),
#  ('attached', 'ready', 'replace', 'couple'),
#  ('ready', 'replace', 'couple', 'years'),
#  ('replace', 'couple', 'years', 'u'),
#  ('couple', 'years', 'u', 'better'),
#  ('years', 'u', 'better', 'spending'),
#  ('u', 'better', 'spending', 'extra'),
#  ('better', 'spending', 'extra', 'better'),
#  ('spending', 'extra', 'better', 'product'),
#  ('extra', 'better', 'product', 'upgrading'),
#  ('better', 'product', 'upgrading', 'standard'),
#  ('product', 'upgrading', 'standard', 'round'),
#  ('upgrading', 'standard', 'round', 'bowl'),
#  ('standard', 'round', 'bowl', 'going'),
#  ('round', 'bowl', 'going', 'want'),
#  ('bowl', 'going', 'want', 'get'),
#  ('going', 'want', 'get', 'inch'),
#  ('want', 'get', 'inch', 'supply'),
#  ('get', 'inch', 'supply', 'line'),
#  ('inch', 'supply', 'line', 'taller'),
#  ('supply', 'line', 'taller', 'expected'),
#  ('line', 'taller', 'expected', 'nice'),
#  ('taller', 'expected', 'nice', 'poop'),
#  ('expected', 'nice', 'poop', 'glacier'),
#  ('nice', 'poop', 'glacier', 'bay'),
#  ('poop', 'glacier', 'bay', 'toilet'),
#  ('glacier', 'bay', 'toilet', 'works'),
#  ('bay', 'toilet', 'works', 'well'),
#  ('toilet', 'works', 'well', 'flush'),
#  ('works', 'well', 'flush', 'water'),
#  ('well', 'flush', 'water', 'use'),
#  ('flush', 'water', 'use', 'efficient'),
#  ('water', 'use', 'efficient', 'taller'),
#  ('use', 'efficient', 'taller', 'base'),
#  ('efficient', 'taller', 'base', 'great'),
#  ('taller', 'base', 'great', 'especially'),
#  ('base', 'great', 'especially', 'someone'),
#  ('great', 'especially', 'someone', 'heavy'),
#  ('especially', 'someone', 'heavy', 'sturdy'),
#  ('someone', 'heavy', 'sturdy', 'requiring'),
#  ('heavy', 'sturdy', 'requiring', 'installation'),
#  ('sturdy', 'requiring', 'installation', 'great'),
#  ('requiring', 'installation', 'great', 'toilet'),
#  ('installation', 'great', 'toilet', 'economical'),
#  ('great', 'toilet', 'economical', 'cost'),
#  ('toilet', 'economical', 'cost', 'installed'),
#  ('economical', 'cost', 'installed', 'glacier'),
#  ('cost', 'installed', 'glacier', 'bay'),
#  ('installed', 'glacier', 'bay', 'g'),
#  ('glacier', 'bay', 'g', 'flush'),
#  ('bay', 'g', 'flush', 'several'),
#  ('g', 'flush', 'several', 'years'),
#  ('flush', 'several', 'years', 'ago'),
#  ('several', 'years', 'ago', 'toilet'),
#  ('years', 'ago', 'toilet', 'flush'),
#  ('ago', 'toilet', 'flush', 'quite'),
#  ('toilet', 'flush', 'quite', 'well'),
#  ('flush', 'quite', 'well', 'older'),
#  ('quite', 'well', 'older', 'toilet'),
#  ('well', 'older', 'toilet', 'nice'),
#  ('older', 'toilet', 'nice', 'toilet'),
#  ('toilet', 'nice', 'toilet', 'little'),
#  ('nice', 'toilet', 'little', 'water'),
#  ('toilet', 'little', 'water', 'bowl'),
#  ('little', 'water', 'bowl', 'water'),
#  ('water', 'bowl', 'water', 'level'),
#  ('bowl', 'water', 'level', 'adjusted'),
#  ('water', 'level', 'adjusted', 'way'),
#  ('level', 'adjusted', 'way', 'still'),
#  ('adjusted', 'way', 'still', 'enough'),
#  ('way', 'still', 'enough', 'water'),
#  ('still', 'enough', 'water', 'efficient'),
#  ('enough', 'water', 'efficient', 'flush'),
#  ('water', 'efficient', 'flush', 'water'),
#  ('efficient', 'flush', 'water', 'savings'),
#  ('flush', 'water', 'savings', 'toilet'),
#  ('water', 'savings', 'toilet', 'would'),
#  ('savings', 'toilet', 'would', 'return'),
#  ('toilet', 'would', 'return', 'nightmare'),
#  ('would', 'return', 'nightmare', 'installed'),
#  ('return', 'nightmare', 'installed', 'disappointed'),
#  ('nightmare', 'installed', 'disappointed', 'toilet'),
#  ('installed', 'disappointed', 'toilet', 'made'),
#  ('disappointed', 'toilet', 'made', 'concrete'),
#  ('toilet', 'made', 'concrete', 'twice'),
#  ('made', 'concrete', 'twice', 'heavy'),
#  ('concrete', 'twice', 'heavy', 'regular'),
#  ('twice', 'heavy', 'regular', 'toilet'),
#  ('heavy', 'regular', 'toilet', 'love'),
#  ('regular', 'toilet', 'love', 'tank'),
#  ('toilet', 'love', 'tank', 'lid'),
#  ('love', 'tank', 'lid', 'fits'),
#  ('tank', 'lid', 'fits', 'weird'),
#  ('lid', 'fits', 'weird', 'keep'),
#  ('fits', 'weird', 'keep', 'wiggling'),
#  ('weird', 'keep', 'wiggling', 'till'),
#  ('keep', 'wiggling', 'till', 'wont'),
#  ('wiggling', 'till', 'wont', 'fall'),
#  ('till', 'wont', 'fall', 'trust'),
#  ('wont', 'fall', 'trust', 'fits'),
#  ('fall', 'trust', 'fits', 'installed'),
#  ('trust', 'fits', 'installed', 'toilet'),
#  ('fits', 'installed', 'toilet', 'everything'),
#  ('installed', 'toilet', 'everything', 'installed'),
#  ('toilet', 'everything', 'installed', 'easily'),
#  ('everything', 'installed', 'easily', 'came'),
#  ('installed', 'easily', 'came', 'bolt'),
#  ('easily', 'came', 'bolt', 'tank'),
#  ('came', 'bolt', 'tank', 'comes'),
#  ('bolt', 'tank', 'comes', 'two'),
#  ('tank', 'comes', 'two', 'wing'),
#  ('comes', 'two', 'wing', 'nuts'),
#  ('two', 'wing', 'nuts', 'impossible'),
#  ('wing', 'nuts', 'impossible', 'turn'),
#  ('nuts', 'impossible', 'turn', 'help'),
#  ('impossible', 'turn', 'help', 'time'),
#  ('turn', 'help', 'time', 'loosened'),
#  ('help', 'time', 'loosened', 'middle'),
#  ('time', 'loosened', 'middle', 'nut'),
#  ('loosened', 'middle', 'nut', 'held'),
#  ('middle', 'nut', 'held', 'wing'),
#  ('nut', 'held', 'wing', 'nut'),
#  ('held', 'wing', 'nut', 'place'),
#  ('wing', 'nut', 'place', 'bottom'),
#  ('nut', 'place', 'bottom', 'person'),
#  ('place', 'bottom', 'person', 'screwed'),
#  ('bottom', 'person', 'screwed', 'screw'),
#  ('person', 'screwed', 'screw', 'top'),
#  ('screwed', 'screw', 'top', 'tightened'),
#  ('screw', 'top', 'tightened', 'middle'),
#  ('top', 'tightened', 'middle', 'nut'),
#  ('tightened', 'middle', 'nut', 'guess'),
#  ('middle', 'nut', 'guess', 'that'),
#  ('nut', 'guess', 'that', 's'),
#  ('guess', 'that', 's', 'someone'),
#  ('that', 's', 'someone', 'else'),
#  ('s', 'someone', 'else', 'left'),
#  ('someone', 'else', 'left', 'review'),
#  ('else', 'left', 'review', 'tank'),
#  ('left', 'review', 'tank', 'doesn'),
#  ('review', 'tank', 'doesn', 't'),
#  ('tank', 'doesn', 't', 'sit'),
#  ('doesn', 't', 'sit', 'strait'),
#  ('t', 'sit', 'strait', 'little'),
#  ('sit', 'strait', 'little', 'water'),
#  ('strait', 'little', 'water', 'tank'),
#  ('little', 'water', 'tank', 'monitor'),
#  ('water', 'tank', 'monitor', 'works'),
#  ('tank', 'monitor', 'works', 'flap'),
#  ('monitor', 'works', 'flap', 'flush'),
#  ('works', 'flap', 'flush', 'falls'),
#  ('flap', 'flush', 'falls', 'second'),
#  ('flush', 'falls', 'second', 'let'),
#  ('falls', 'second', 'let', 'go'),
#  ('second', 'let', 'go', 'play'),
#  ('let', 'go', 'play', 'see'),
#  ('go', 'play', 'see', 'works'),
#  ('play', 'see', 'works', 'would'),
#  ('see', 'works', 'would', 'say'),
#  ('works', 'would', 'say', 'bowl'),
#  ('would', 'say', 'bowl', 'nice'),
#  ('say', 'bowl', 'nice', 'however'),
#  ('bowl', 'nice', 'however', 'seat'),
#  ('nice', 'however', 'seat', 'made'),
#  ('however', 'seat', 'made', 'thin'),
#  ('seat', 'made', 'thin', 'plastic'),
#  ('made', 'thin', 'plastic', 'able'),
#  ('thin', 'plastic', 'able', 'see'),
#  ('plastic', 'able', 'see', 'seat'),
#  ('able', 'see', 'seat', 'installed'),
#  ('see', 'seat', 'installed', 'went'),
#  ('seat', 'installed', 'went', 'back'),
#  ('installed', 'went', 'back', 'home'),
#  ('went', 'back', 'home', 'depot'),
#  ('back', 'home', 'depot', 'manager'),
#  ('home', 'depot', 'manager', 'let'),
#  ('depot', 'manager', 'let', 'get'),
#  ('manager', 'let', 'get', 'different'),
#  ('let', 'get', 'different', 'seat'),
#  ('get', 'different', 'seat', 'made'),
#  ('different', 'seat', 'made', 'better'),
#  ('seat', 'made', 'better', 'anyone'),
#  ('made', 'better', 'anyone', 'sit'),
#  ('better', 'anyone', 'sit', 'they'),
#  ('anyone', 'sit', 'they', 're'),
#  ('sit', 'they', 're', 'mass'),
#  ('they', 're', 'mass', 'marketed'),
#  ('re', 'mass', 'marketed', 'inside'),
#  ('mass', 'marketed', 'inside', 'edges'),
#  ('marketed', 'inside', 'edges', 'seat'),
#  ('inside', 'edges', 'seat', 'horrible'),
#  ('edges', 'seat', 'horrible', 'pain'),
#  ('seat', 'horrible', 'pain', 'almost'),
#  ('horrible', 'pain', 'almost', 'instant'),
#  ('pain', 'almost', 'instant', 'sharp'),
#  ('almost', 'instant', 'sharp', 'edges'),
#  ('instant', 'sharp', 'edges', 'belong'),
#  ('sharp', 'edges', 'belong', 'installed'),
#  ('edges', 'belong', 'installed', 'difficult'),
#  ('belong', 'installed', 'difficult', 'went'),
#  ('installed', 'difficult', 'went', 'pretty'),
#  ('difficult', 'went', 'pretty', 'quickly'),
#  ('went', 'pretty', 'quickly', 'works'),
#  ('pretty', 'quickly', 'works', 'greathappy'),
#  ('quickly', 'works', 'greathappy', 'purchase'),
#  ('works', 'greathappy', 'purchase', 'easy'),
#  ('greathappy', 'purchase', 'easy', 'install'),
#  ('purchase', 'easy', 'install', 'recently'),
#  ('easy', 'install', 'recently', 'visited'),
#  ('install', 'recently', 'visited', 'sister'),
#  ('recently', 'visited', 'sister', 'florida'),
#  ('visited', 'sister', 'florida', 'leaking'),
#  ('sister', 'florida', 'leaking', 'toilet'),
#  ('florida', 'leaking', 'toilet', 'turned'),
#  ('leaking', 'toilet', 'turned', 'cracked'),
#  ('toilet', 'turned', 'cracked', 'tank'),
#  ('turned', 'cracked', 'tank', 'went'),
#  ('cracked', 'tank', 'went', 'nearby'),
#  ('tank', 'went', 'nearby', 'home'),
#  ('went', 'nearby', 'home', 'depot'),
#  ('nearby', 'home', 'depot', 'found'),
#  ('home', 'depot', 'found', 'great'),
#  ('depot', 'found', 'great', 'deal'),
#  ('found', 'great', 'deal', 'glacier'),
#  ('great', 'deal', 'glacier', 'bay'),
#  ('deal', 'glacier', 'bay', 'high'),
#  ('glacier', 'bay', 'high', 'efficiency'),
#  ('bay', 'high', 'efficiency', 'toilet'),
#  ('high', 'efficiency', 'toilet', 'came'),
#  ('efficiency', 'toilet', 'came', 'complete'),
#  ('toilet', 'came', 'complete', 'everything'),
#  ('came', 'complete', 'everything', 'needed'),
#  ('complete', 'everything', 'needed', 'full'),
#  ('everything', 'needed', 'full', 'replacement'),
#  ('needed', 'full', 'replacement', 'installation'),
#  ('full', 'replacement', 'installation', 'uneventful'),
#  ('replacement', 'installation', 'uneventful', 'prime'),
#  ('installation', 'uneventful', 'prime', 'example'),
#  ('uneventful', 'prime', 'example', 'dont'),
#  ('prime', 'example', 'dont', 'spend'),
#  ('example', 'dont', 'spend', 'lot'),
#  ('dont', 'spend', 'lot', 'money'),
#  ('spend', 'lot', 'money', 'get'),
#  ('lot', 'money', 'get', 'high'),
#  ('money', 'get', 'high', 'quality'),
#  ('get', 'high', 'quality', 'product'),
#  ('high', 'quality', 'product', 'inexpensive'),
#  ('quality', 'product', 'inexpensive', 'glacier'),
#  ('product', 'inexpensive', 'glacier', 'bay'),
#  ('inexpensive', 'glacier', 'bay', 'toilets'),
#  ('glacier', 'bay', 'toilets', 'used'),
#  ('bay', 'toilets', 'used', 'great'),
#  ('toilets', 'used', 'great', 'past'),
#  ('used', 'great', 'past', 'decade'),
#  ('great', 'past', 'decade', 'put'),
#  ('past', 'decade', 'put', 'houses'),
#  ('decade', 'put', 'houses', 'without'),
#  ('put', 'houses', 'without', 'ever'),
#  ('houses', 'without', 'ever', 'problems'),
#  ('without', 'ever', 'problems', 'something'),
#  ('ever', 'problems', 'something', 'changed'),
#  ('problems', 'something', 'changed', 'disaster'),
#  ('something', 'changed', 'disaster', 'two'),
#  ('changed', 'disaster', 'two', 'recently'),
#  ('disaster', 'two', 'recently', 'purchased'),
#  ('two', 'recently', 'purchased', 'manufactured'),
#  ('recently', 'purchased', 'manufactured', 'march'),
#  ('purchased', 'manufactured', 'march', 'mexico'),
#  ('manufactured', 'march', 'mexico', 'namce'),
#  ('march', 'mexico', 'namce', 'ceramics'),
#  ('mexico', 'namce', 'ceramics', 'specs'),
#  ('namce', 'ceramics', 'specs', 'wrong'),
#  ('ceramics', 'specs', 'wrong', 'perhaps'),
#  ('specs', 'wrong', 'perhaps', 'used'),
#  ('wrong', 'perhaps', 'used', 'centimeters'),
#  ('perhaps', 'used', 'centimeters', 'mexico'),
#  ('used', 'centimeters', 'mexico', 'instead'),
#  ('centimeters', 'mexico', 'instead', 'inches'),
#  ('mexico', 'instead', 'inches', 'base'),
#  ('instead', 'inches', 'base', 'least'),
#  ('inches', 'base', 'least', 'two'),
#  ('base', 'least', 'two', 'inches'),
#  ('least', 'two', 'inches', 'shorter'),
#  ('two', 'inches', 'shorter', 'used'),
#  ('inches', 'shorter', 'used', 'even'),
#  ('shorter', 'used', 'even', 'might'),
#  ('used', 'even', 'might', 'work'),
#  ('even', 'might', 'work', 'except'),
#  ('might', 'work', 'except', 'tank'),
#  ('work', 'except', 'tank', 'sit'),
#  ('except', 'tank', 'sit', 'level'),
#  ('tank', 'sit', 'level', 'base'),
#  ('sit', 'level', 'base', 'anymore'),
#  ('level', 'base', 'anymore', 'neither'),
#  ('base', 'anymore', 'neither', 'level'),
#  ('anymore', 'neither', 'level', 'sidetoside'),
#  ('neither', 'level', 'sidetoside', 'fronttoback'),
#  ('level', 'sidetoside', 'fronttoback', 'causing'),
#  ('sidetoside', 'fronttoback', 'causing', 'pitch'),
#  ('fronttoback', 'causing', 'pitch', 'forward'),
#  ('causing', 'pitch', 'forward', 'makes'),
#  ('pitch', 'forward', 'makes', 'uncomfortable'),
#  ('forward', 'makes', 'uncomfortable', 'sit'),
#  ('makes', 'uncomfortable', 'sit', 'toilet'),
#  ('uncomfortable', 'sit', 'toilet', 'negates'),
#  ('sit', 'toilet', 'negates', 'elongation'),
#  ('toilet', 'negates', 'elongation', 'urine'),
#  ('negates', 'elongation', 'urine', 'splashes'),
#  ('elongation', 'urine', 'splashes', 'onto'),
#  ('urine', 'splashes', 'onto', 'back'),
#  ('splashes', 'onto', 'back', 'seat'),
#  ('onto', 'back', 'seat', 'one'),
#  ('back', 'seat', 'one', 'stands'),
#  ('seat', 'one', 'stands', 'urinate'),
#  ('one', 'stands', 'urinate', 'one'),
#  ('stands', 'urinate', 'one', 'must'),
#  ('urinate', 'one', 'must', 'hold'),
#  ('one', 'must', 'hold', 'seat'),
#  ('must', 'hold', 'seat', 'entire'),
#  ('hold', 'seat', 'entire', 'time'),
#  ('seat', 'entire', 'time', 'stay'),
#  ('entire', 'time', 'stay', 'would'),
#  ('time', 'stay', 'would', 'mere'),
#  ('stay', 'would', 'mere', 'inconvenience'),
#  ('would', 'mere', 'inconvenience', 'except'),
#  ('mere', 'inconvenience', 'except', 'completely'),
#  ('inconvenience', 'except', 'completely', 'unsanitary'),
#  ('except', 'completely', 'unsanitary', 'since'),
#  ('completely', 'unsanitary', 'since', 'urine'),
#  ('unsanitary', 'since', 'urine', 'back'),
#  ('since', 'urine', 'back', 'seat'),
#  ('urine', 'back', 'seat', 'sit'),
#  ('back', 'seat', 'sit', 'urinate'),
#  ('seat', 'sit', 'urinate', 'disaster'),
#  ('sit', 'urinate', 'disaster', 'longer'),
#  ('urinate', 'disaster', 'longer', 'buy'),
#  ('disaster', 'longer', 'buy', 'toilets'),
#  ('longer', 'buy', 'toilets', 'home'),
#  ('buy', 'toilets', 'home', 'depotglacier'),
#  ('toilets', 'home', 'depotglacier', 'bay'),
#  ('home', 'depotglacier', 'bay', 'please'),
#  ('depotglacier', 'bay', 'please', 'return'),
#  ('bay', 'please', 'return', 'previous'),
#  ('please', 'return', 'previous', 'manufacturer'),
#  ('return', 'previous', 'manufacturer', 'specs'),
#  ('previous', 'manufacturer', 'specs', 'toilets'),
#  ('manufacturer', 'specs', 'toilets', 'would'),
#  ('specs', 'toilets', 'would', 'also'),
#  ('toilets', 'would', 'also', 'nice'),
#  ('would', 'also', 'nice', 'home'),
#  ('also', 'nice', 'home', 'depot'),
#  ('nice', 'home', 'depot', 'would'),
#  ('home', 'depot', 'would', 'acknowledge'),
#  ('depot', 'would', 'acknowledge', 'toilets'),
#  ('would', 'acknowledge', 'toilets', 'manufactured'),
#  ('acknowledge', 'toilets', 'manufactured', 'mexico'),
#  ('toilets', 'manufactured', 'mexico', 'defective'),
#  ('manufactured', 'mexico', 'defective', 'issue'),
#  ('mexico', 'defective', 'issue', 'refunds'),
#  ('defective', 'issue', 'refunds', 'us'),
#  ('issue', 'refunds', 'us', 'purchased'),
#  ('refunds', 'us', 'purchased', 'replacing'),
#  ('us', 'purchased', 'replacing', 'old'),
#  ('purchased', 'replacing', 'old', 'toilets'),
#  ('replacing', 'old', 'toilets', 'model'),
#  ('old', 'toilets', 'model', 'worked'),
#  ('toilets', 'model', 'worked', 'well'),
#  ('model', 'worked', 'well', 'residents'),
#  ('worked', 'well', 'residents', 'dry'),
#  ('well', 'residents', 'dry', 'assemble'),
#  ('residents', 'dry', 'assemble', 'first'),
#  ('dry', 'assemble', 'first', 'include'),
#  ('assemble', 'first', 'include', 'tank'),
#  ('first', 'include', 'tank', 'toilet'),
#  ('include', 'tank', 'toilet', 'gasket'),
#  ('tank', 'toilet', 'gasket', 'screws'),
#  ('toilet', 'gasket', 'screws', 'didnt'),
#  ('gasket', 'screws', 'didnt', 'base'),
#  ('screws', 'didnt', 'base', 'installed'),
#  ('didnt', 'base', 'installed', 'bought'),
#  ('base', 'installed', 'bought', 'used'),
#  ('installed', 'bought', 'used', 'thicker'),
#  ('bought', 'used', 'thicker', 'gasket'),
#  ('used', 'thicker', 'gasket', 'per'),
#  ('thicker', 'gasket', 'per', 'reviews'),
#  ('gasket', 'per', 'reviews', 'added'),
#  ('per', 'reviews', 'added', 'water'),
#  ('reviews', 'added', 'water', 'per'),
#  ('added', 'water', 'per', 'instructions'),
#  ('water', 'per', 'instructions', 'attempted'),
#  ('per', 'instructions', 'attempted', 'attach'),
#  ('instructions', 'attempted', 'attach', 'tank'),
#  ('attempted', 'attach', 'tank', 'see'),
#  ('attach', 'tank', 'see', 'pic'),
#  ('tank', 'see', 'pic', 'aint'),
#  ('see', 'pic', 'aint', 'centered'),
#  ('pic', 'aint', 'centered', 'hd'),
#  ('aint', 'centered', 'hd', 'opened'),
#  ('centered', 'hd', 'opened', 'next'),
#  ('hd', 'opened', 'next', 'box'),
#  ('opened', 'next', 'box', 'found'),
#  ('next', 'box', 'found', 'next'),
#  ('box', 'found', 'next', 'unit'),
#  ('found', 'next', 'unit', 'hole'),
#  ...]

# %%
# ## Count the trigrams with the same set of words
# trigram_count = defaultdict(set)

# for word in trigrams[6]:
#     key = frozenset(word)
#     trigram_count[key].add(word)

# # Print the trigram counts
# for key, amount in trigram_count.items():
#     count = len(amount)
#     print(f"{key}: {count}")

# %%
# connect the three words together 
words = [0] * 8
for i in range(8):
    words[i] = [' '.join(tr) for tr in trigrams[i]]

# %% [markdown]
# ### Frequency Analysis

# %%
# select the data 
n = int(input('Which one do you want to look at? (0-7)'))

word_frequency = FreqDist(trigrams[n])

# Identify co-occurring trigrams
cooccurring_trigrams = []
for trigram in word_frequency:
    if word_frequency[trigram] > 1:
        cooccurring_trigrams.append(trigram)

word_frequency.most_common(10)

# word_frequency.plot(30,cumulative=False)
# plt.show()
# Out:
# Which one do you want to look at? (0-7)1
# [(('new', 'water', 'supply', 'line'), 4),
#  (('clean', 'high', 'efficiency', 'elongated'), 3),
#  (('remove', 'old', 'toilet', 'install'), 2),
#  (('chair', 'height', 'elongated', 'toilet'), 2),
#  (('works', 'well', 'easy', 'install'), 2),
#  (('easy', 'install', 'necessary', 'parts'), 2),
#  (('purchase', 'longer', 'supply', 'line'), 2),
#  (('american', 'standard', 'toilet', 'installation'), 2),
#  (('except', 'water', 'supply', 'line'), 2),
#  (('existing', 'water', 'supply', 'line'), 2)]

# %% [markdown]
# ### Topic Modeling
# #### Latent Dirichlet Allocation (LDA), which is a popular unsupervised learning algorithm used for topic modeling.

# %%
from gensim import corpora, models

# %%
# Step 1: select the data 
n = int(input('Which one do you want to look at? (0-7)'))

# Step 2: Create a dictionary of words and convert the text into a bag-of-words format
dictionary = corpora.Dictionary([words[n]])
corpus = [dictionary.doc2bow([word]) for word in words[n]]

# Step 3: Apply LDA to the corpus to identify topics in the text
lda_model = models.LdaModel(corpus, num_topics=3, id2word=dictionary, passes=10)

# Step 4: Print the topics and the top words associated with each topic
for i, topic in lda_model.show_topics(formatted=True, num_topics=3, num_words=4):
    print("Topic {}: {}".format(i, topic))
# Out:
# Which one do you want to look at? (0-7)1
# Topic 0: 0.001*"easy clean toilet seat" + 0.001*"easy install works great" + 0.000*"wish made years sooner" + 0.000*"fine handles number jobs"
# Topic 1: 0.001*"clean high efficiency elongated" + 0.000*"american standard clean high" + 0.000*"efficient right height elongated" + 0.000*"toilet flushes well clean"
# Topic 2: 0.001*"much better previous toilet" + 0.000*"easy install works well" + 0.000*"new water supply line" + 0.000*"enough water rinse bowl"
